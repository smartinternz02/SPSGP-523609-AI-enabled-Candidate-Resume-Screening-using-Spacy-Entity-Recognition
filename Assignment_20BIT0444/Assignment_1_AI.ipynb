# %%
# Task 1
import numpy as np
import pandas as pd

# Generate random values
data = np.random.randn(4, 4)  # 4 features, 4 observations

# Create DataFrame
df = pd.DataFrame(data, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'])

# Print the DataFrame
print(df)
# Out:
#    Feature 1  Feature 2  Feature 3  Feature 4
# 0   0.195323   0.319482   0.160431   1.646747
# 1  -1.567073   0.673638  -0.176650  -0.252301
# 2   0.260330   0.802700  -1.328567  -0.861187
# 3   0.440931  -0.612843   0.271705   0.626995

# %%
# Task 2
# Rename column names
df = df.rename(columns={'Feature 1': 'Random value 1',
                        'Feature 2': 'Random value 2',
                        'Feature 3': 'Random value 3',
                        'Feature 4': 'Random value 4'})

# Print the updated DataFrame
print(df)
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.195323        0.319482        0.160431        1.646747
# 1       -1.567073        0.673638       -0.176650       -0.252301
# 2        0.260330        0.802700       -1.328567       -0.861187
# 3        0.440931       -0.612843        0.271705        0.626995

# %%
# Task 3
# Calculate descriptive statistics
statistics = df.describe()

# Print the descriptive statistics
print(statistics)
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean        -0.167623        0.295744       -0.268270        0.290063
# std          0.938735        0.639245        0.732116        1.091429
# min         -1.567073       -0.612843       -1.328567       -0.861187
# 25%         -0.245276        0.086401       -0.464629       -0.404523
# 50%          0.227826        0.496560       -0.008109        0.187347
# 75%          0.305480        0.705903        0.188250        0.881933
# max          0.440931        0.802700        0.271705        1.646747

# %%
# Task 4
# Check for null values
null_values = df.isnull().sum()
print("Null Values:")
print(null_values)

# Find data types of columns
data_types = df.dtypes
print("\nData Types:")
print(data_types)
# Out:
# Null Values:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64
#
# Data Types:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
# Task 5
# Display columns using loc method
columns_loc = df.loc[:, ['Random value 2', 'Random value 3']]
print("Columns using loc method:")
print(columns_loc)

# Display columns using index location method
columns_index_loc = df.iloc[:, [1, 2]]
print("\nColumns using index location method:")
print(columns_index_loc)
# Out:
# Columns using loc method:
#    Random value 2  Random value 3
# 0        0.319482        0.160431
# 1        0.673638       -0.176650
# 2        0.802700       -1.328567
# 3       -0.612843        0.271705
#
# Columns using index location method:
#    Random value 2  Random value 3
# 0        0.319482        0.160431
# 1        0.673638       -0.176650
# 2        0.802700       -1.328567
# 3       -0.612843        0.271705
